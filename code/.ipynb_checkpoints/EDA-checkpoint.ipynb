# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression,Ridge, RidgeCV, Lasso, LassoCV 
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# Import ARIMA model.
from statsmodels.tsa.arima_model import ARIMA
from sklearn.model_selection import train_test_split

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
month_mole_carbon = pd.read_csv('../data/co2/mole_fraction_of_carbon_dioxide_in_air_input4MIPs_GHGConcentrations_CMIP_UoM-CMIP-1-1-0_gr3-GMNHSH_000001-201412.csv')
year_mole_carbon = pd.read_csv('../data/co2/mole_fraction_of_carbon_dioxide_in_air_input4MIPs_GHGConcentrations_CMIP_UoM-CMIP-1-1-0_gr3-GMNHSH_0000-2014.csv')

# %%
atx_sm = pd.read_csv('../data/meteorological/atx_metric_sm.csv')
atx_lg = pd.read_csv('../data/meteorological/atx_metric_lg.csv')
world = pd.read_csv('../data/meteorological/world.csv',index_col=0)

# %%
c_by_sect = pd.read_csv('../data/carbon_by_sector/sector_90-18.csv', index_col=0)

# %%
methane = pd.read_csv('../data/methane/adjusted.csv',index_col=0)

# %%
atx_sm['date'] = pd.to_datetime(atx_sm['DATE'])
atx_lg['date'] = pd.to_datetime(atx_lg['DATE'])

# %%
year_mole_carbon = year_mole_carbon[year_mole_carbon['year']>=1970]

# %%
world = world.iloc[4:]
world.index= pd.to_datetime(world.index)
year_mole_carbon.index= pd.to_datetime(year_mole_carbon.year,format="%Y")

# %%
world['January-December'] = world[' January-December'].astype('float64')
world = world.drop(labels = ' January-December', axis =1)

# %%
c_by_sect = c_by_sect.transpose()

# %%
year_mole_carbon[year_mole_carbon['data_mean_global']>=300].plot(y='data_mean_global');

# %%
na_years = [
    'Indicator Code',
    'Indicator Name',
    'Country Code',
    '1960',
    '1961',
    '1962',
    '1963',
    '1964',
    '1965',
    '1966',
    '1967',
    '1968',
    '1969',

    '2013',
    '2014',
    '2015',
    '2016',
    '2017',
    '2018',
    '2019',]
methane = methane.drop(na_years, axis=1)
methane_trans = methane.transpose()

# %%
methane_trans['World'].plot();
methane.nlargest(5,'2012')
# Out:
#                              1970          1971          1972          1973  \
# Country Name
# World                5.305820e+06  5.145430e+06  5.360610e+06  5.421500e+06
# IDA & IBRD total     3.720686e+06  3.577293e+06  3.767757e+06  3.802106e+06
# Low & middle income  3.587129e+06  3.437779e+06  3.622250e+06  3.651577e+06
# Middle income        3.245348e+06  3.177119e+06  3.355407e+06  3.368864e+06
# IBRD only            2.936443e+06  2.928403e+06  3.094553e+06  3.079453e+06
#
#                              1974          1975          1976          1977  \
# Country Name
# World                5.379140e+06  5.503270e+06  5.649430e+06  5.796380e+06
# IDA & IBRD total     3.754305e+06  3.878533e+06  3.989010e+06  4.140434e+06
# Low & middle income  3.597123e+06  3.714630e+06  3.821891e+06  3.971140e+06
# Middle income        3.350239e+06  3.439027e+06  3.554098e+06  3.669661e+06
# IBRD only            3.102318e+06  3.187412e+06  3.306307e+06  3.390626e+06
#
#                              1978          1979  ...          2004  \
# Country Name                                     ...
# World                5.795950e+06  5.972760e+06  ...  7.088150e+06
# IDA & IBRD total     4.156635e+06  4.291244e+06  ...  5.556343e+06
# Low & middle income  3.985261e+06  4.116033e+06  ...  5.432801e+06
# Middle income        3.687561e+06  3.767545e+06  ...  5.039923e+06
# IBRD only            3.397110e+06  3.459617e+06  ...  4.517457e+06
#
#                              2005          2006          2007          2008  \
# Country Name
# World                7.275910e+06  7.617940e+06  7.697440e+06  7.643170e+06
# IDA & IBRD total     5.770384e+06  6.106188e+06  6.168473e+06  6.127093e+06
# Low & middle income  5.645237e+06  5.978172e+06  6.041140e+06  6.001248e+06
# Middle income        5.239528e+06  5.438728e+06  5.291793e+06  5.434224e+06
# IBRD only            4.716283e+06  4.911653e+06  4.708884e+06  4.868609e+06
#
#                              2009          2010          2011          2012  \
# Country Name
# World                7.774920e+06  7.815790e+06  7.927061e+06  8.014067e+06
# IDA & IBRD total     6.269204e+06  6.310848e+06  6.425679e+06  6.528698e+06
# Low & middle income  6.143816e+06  6.185837e+06  6.301019e+06  6.404259e+06
# Middle income        5.577527e+06  5.630616e+06  5.740063e+06  5.837567e+06
# IBRD only            5.004865e+06  5.046580e+06  5.148696e+06  5.239002e+06
#
#                      Unnamed: 64
# Country Name
# World                        NaN
# IDA & IBRD total             NaN
# Low & middle income          NaN
# Middle income                NaN
# IBRD only                    NaN
#
# [5 rows x 44 columns]

# %%
methane_trans['World'].plot();

# %%
year_mole_carbon[year_mole_carbon['year']>=1970]['data_mean_global'].plot()

# %%
atx_lg.index = atx_lg['date']
atx_lg.head()
# Out:
#                 STATION                             NAME  LATITUDE  LONGITUDE  \
# date
# 1945-03-01  USW00093901  DALLAS HENSLEY FIELD NAS, TX US  32.73333  -96.96667
# 1945-04-01  USW00093901  DALLAS HENSLEY FIELD NAS, TX US  32.73333  -96.96667
# 1945-05-01  USW00093901  DALLAS HENSLEY FIELD NAS, TX US  32.73333  -96.96667
# 1945-06-01  USW00093901  DALLAS HENSLEY FIELD NAS, TX US  32.73333  -96.96667
# 1945-07-01  USW00093901  DALLAS HENSLEY FIELD NAS, TX US  32.73333  -96.96667
#
#             ELEVATION     DATE  AWND AWND_ATTRIBUTES  DYTS  DYTS_ATTRIBUTES  \
# date
# 1945-03-01      150.0  1945-03   NaN             NaN  13.0              NaN
# 1945-04-01      150.0  1945-04   NaN             NaN   4.0              NaN
# 1945-05-01      150.0  1945-05   NaN             NaN   6.0              NaN
# 1945-06-01      150.0  1945-06   NaN             NaN   7.0              NaN
# 1945-07-01      150.0  1945-07   NaN             NaN   7.0              NaN
#
#             TAVG TAVG_ATTRIBUTES  WSFG WSFG_ATTRIBUTES       date
# date
# 1945-03-01  16.8              ,X   NaN             NaN 1945-03-01
# 1945-04-01  17.8              ,X   NaN             NaN 1945-04-01
# 1945-05-01  22.5              ,X   NaN             NaN 1945-05-01
# 1945-06-01  26.8              ,X   NaN             NaN 1945-06-01
# 1945-07-01  27.6              ,X   NaN             NaN 1945-07-01

# %%
atx_abg_temp = atx_lg['TAVG'].resample("Y").mean()
atx_abg_temp.dropna(inplace=True)
atx_abg_temp.loc[atx_abg_temp.index > '1970-10-16 08:00:00'].plot();

# %%
world.loc[world.index > '1970-10-16 08:00:00'].plot()

# %%
world.index = world.index.strftime('%Y')

# %%
methane_w = methane_trans['World'].dropna()
methane_w.index = pd.to_datetime(methane_w.index)

# %%
aggr = pd.DataFrame(methane_w).join(world.loc[world.index > '1969-10-16 08:00:00'])

# %%
aggr = aggr.join(year_mole_carbon)

# %%
aggr= aggr.drop(['data_mean_nh', 'data_mean_sh','year'],axis=1)

# %%
aggr.columns = ['world_methane', 'temp_anomaly','world_carbon']

# %%
aggr['temp_anomaly'].diff(1).plot()
aggr['temp_anomaly'].diff(1).diff(1).plot()

# %%
aggr.head()
# Out:
#             world_methane  temp_anomaly  world_carbon
# 1970-01-01      5305820.0          0.06    324.782956
# 1971-01-01      5145430.0         -0.07    325.399955
# 1972-01-01      5360610.0          0.04    327.348954
# 1973-01-01      5421500.0          0.19    329.908953
# 1974-01-01      5379140.0         -0.06    330.755953

# %%
adfuller(aggr['temp_anomaly'])
# Out:
# (-1.4805584025575678,
#  0.5431059633143156,
#  7,
#  35,
#  {'1%': -3.6327426647230316,
#   '5%': -2.9485102040816327,
#   '10%': -2.6130173469387756},
#  -60.39130354158499)

# %%
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %%
interpret_dftest(adfuller(aggr['temp_anomaly']))
# Out:
# Test Statistic   -1.480558
# p-value           0.543106
# dtype: float64

# %%
aggr.head()
# Out:
#             world_methane  temp_anomaly  world_carbon
# 1970-01-01      5305820.0          0.06    324.782956
# 1971-01-01      5145430.0         -0.07    325.399955
# 1972-01-01      5360610.0          0.04    327.348954
# 1973-01-01      5421500.0          0.19    329.908953
# 1974-01-01      5379140.0         -0.06    330.755953

# %%
aggr['temp_a_diff_1']= aggr['temp_anomaly'].diff(1)
aggr['target'] = aggr['temp_a_diff_1'].shift(-1)
aggr['temp_a_diff_2']= aggr['temp_a_diff_1'].diff(1)
aggr['world_methane_diff_1']= aggr['world_methane'].diff(1)
aggr['world_methane_diff_2']= aggr['world_methane'].diff(1).diff(1)
aggr['world_carbon_diff_1']= aggr['world_carbon'].diff(1)
aggr['world_carbon_diff_2']= aggr['world_carbon'].diff(1).diff(1)

# %%
aggr = aggr.dropna()

# %%
plt.figure(figsize = (15,15))

# Get correlation of variables.

corr = aggr.drop(columns=['temp_anomaly'],axis=1).corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# sns.pairplot(aggr)

# %%
#features = aggr.drop(['target'],axis=1).columns
features = ['world_methane_diff_2', 'world_carbon_diff_2', 'temp_a_diff_1', ]
X= aggr[features]
y= aggr['target']

# %%
def evaluate_model(model, X, y):
    y_train_hat = model.predict(X)
    # give me the r2, mse, and rmse for our training split
    print(f'R2 Score: {r2_score(y, y_train_hat)}')
    print(f'MSE: {mean_squared_error(y, y_train_hat)}')
    print(f'RMSE: {mean_squared_error(y, y_train_hat)**0.5}')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
linreg = LinearRegression()
linreg.fit(X_train_sc, y_train)
linreg.score(X_test_sc,y_test)
# Out:
# 0.22238463653106333

# %%
ridge_model = Ridge(alpha=8,fit_intercept=False,solver= 'saga')
ridge_model.fit(X_train_sc, y_train)

# Evaluate model using R2.
print(ridge_model.score(X_train_sc, y_train))
print(ridge_model.score(X_test_sc, y_test))
evaluate_model(ridge_model, X_test_sc, y_test)
# Out:
# 0.4306434141902181
# 0.3925605873170058
# R2 Score: 0.3925605873170058
# MSE: 0.003690801871461873
# RMSE: 0.060751970103543745

# %%
pred = ridge_model.predict(X_test_sc)

# %%
df = pd.DataFrame(y_test)
df['pred'] = pred

# %%
residuals_ridge = (y_test) - pred

# %%
residuals_ridge.mean()
# Out:
# -0.0019477103256572551

# %%
residuals_ridge.sort_values()
# Out:
# 2010-01-01   -0.120987
# 2006-01-01   -0.058570
# 2003-01-01   -0.033894
# 2007-01-01   -0.032920
# 2005-01-01   -0.000050
# 2011-01-01    0.005609
# 2002-01-01    0.012132
# 2004-01-01    0.037867
# 2009-01-01    0.073085
# 2008-01-01    0.098251
# Name: target, dtype: float64

# %%
plt.figure(figsize=(10,8))
fig1 = sns.scatterplot(pred, residuals_ridge );
fig1.set(xlabel = 'Temperature Anomaly', ylabel= 'Residual', title = 'Residuals Plot');
sns.set(font_scale=1)

# %%
df
# Out:
#             target      pred
# 2002-01-01    0.02  0.007868
# 2003-01-01   -0.06 -0.026106
# 2004-01-01    0.09  0.052133
# 2005-01-01   -0.03 -0.029950
# 2006-01-01   -0.02  0.038570
# 2007-01-01   -0.07 -0.037080
# 2008-01-01    0.10  0.001749
# 2009-01-01    0.08  0.006915
# 2010-01-01   -0.15 -0.029013
# 2011-01-01    0.06  0.054391

# %%
ax1 = df.reset_index().plot(kind='scatter',x='index', y='target', color='r')    
ax2 = df.reset_index().plot(kind='scatter',x='index', y='pred', color='g', ax=ax1)

# %%
l_alphas = np.logspace(-3, 0, 100)
lasso_cv = LassoCV(alphas=l_alphas, cv=5, max_iter=5000)
lasso_cv.fit(X_train_sc, y_train)
# Out:
# LassoCV(alphas=array([0.001     , 0.00107227, 0.00114976, 0.00123285, 0.00132194,
#        0.00141747, 0.00151991, 0.00162975, 0.00174753, 0.00187382,
#        0.00200923, 0.00215443, 0.00231013, 0.00247708, 0.00265609,
#        0.00284804, 0.00305386, 0.00327455, 0.00351119, 0.00376494,
#        0.00403702, 0.00432876, 0.00464159, 0.00497702, 0.0053367 ,
#        0.00572237, 0.00613591, 0.00657933, 0.0070548 , 0.00756463,
#        0.008...
#        0.09326033, 0.1       , 0.10722672, 0.1149757 , 0.12328467,
#        0.13219411, 0.14174742, 0.15199111, 0.16297508, 0.17475284,
#        0.18738174, 0.2009233 , 0.21544347, 0.23101297, 0.24770764,
#        0.26560878, 0.28480359, 0.30538555, 0.32745492, 0.35111917,
#        0.37649358, 0.40370173, 0.43287613, 0.46415888, 0.49770236,
#        0.53366992, 0.57223677, 0.61359073, 0.65793322, 0.70548023,
#        0.75646333, 0.81113083, 0.869749  , 0.93260335, 1.        ]),
#         cv=5, max_iter=5000)

# %%
pred = lasso_cv.predict(X_test_sc)
df['pred'] = pred

# %%
ax1 = df.reset_index().plot(kind='scatter',x='index', y='target', color='r')    
ax2 = df.reset_index().plot(kind='scatter',x='index', y='pred', color='g', ax=ax1)

# %%
residuals_lasso = (y_test) - pred
residuals_lasso.mean()
# Out:
# -0.02036538091163425

# %%
residuals_lasso.sort_values()
# Out:
# 2010-01-01   -0.137840
# 2006-01-01   -0.077327
# 2003-01-01   -0.049818
# 2007-01-01   -0.049760
# 2005-01-01   -0.019570
# 2011-01-01   -0.009685
# 2002-01-01   -0.006865
# 2004-01-01    0.014950
# 2009-01-01    0.046735
# 2008-01-01    0.085526
# Name: target, dtype: float64

# %%
plt.figure(figsize=(10,8))
fig1 = sns.scatterplot(pred, residuals_lasso );
fig1.set(xlabel = 'Temperature Anomaly', ylabel= 'Residual', title = 'Residuals Plot');
sns.set(font_scale=1)

# %%
evaluate_model(lasso_cv, X_test_sc, y_test)
# Out:
# R2 Score: 0.3386538455246728
# MSE: 0.004018339234592089
# RMSE: 0.06339037178146291

# %%
evaluate_model(ridge_model, X_test_sc, y_test)
# Out:
# R2 Score: 0.3925605873170058
# MSE: 0.003690801871461873
# RMSE: 0.060751970103543745

# %%
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# Confirm.
X_train.head()
# Out:
#             const  world_methane_diff_2  world_carbon_diff_2  temp_a_diff_1
# 1972-01-01    1.0              375570.0                1.332           0.11
# 1973-01-01    1.0             -154290.0                0.611           0.15
# 1974-01-01    1.0             -103250.0               -1.713          -0.25
# 1975-01-01    1.0              166490.0               -0.776           0.07
# 1976-01-01    1.0               22030.0                0.647          -0.08

# %%
X_train.dropna(inplace=True)
y_train = y_train[X_train.index]

# %%
lm = sm.OLS(y_train, X_train)

# %%
# Then we fit our model.
lm_results = lm.fit()

# %%
print(lm_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     8.102
# Date:                Sat, 05 Sep 2020   Prob (F-statistic):           0.000566
# Time:                        17:53:28   Log-Likelihood:                 28.073
# No. Observations:                  30   AIC:                            -48.15
# Df Residuals:                      26   BIC:                            -42.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0247      0.019      1.309      0.202      -0.014       0.064
# world_methane_diff_2  2.307e-07   5.78e-08      3.993      0.000    1.12e-07    3.49e-07
# world_carbon_diff_2      0.0321      0.035      0.927      0.363      -0.039       0.103
# temp_a_diff_1           -0.3982      0.174     -2.286      0.031      -0.756      -0.040
# ==============================================================================
# Omnibus:                        0.085   Durbin-Watson:                   2.435
# Prob(Omnibus):                  0.958   Jarque-Bera (JB):                0.183
# Skew:                          -0.111   Prob(JB):                        0.912
# Kurtosis:                       2.688   Cond. No.                     3.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
olm_results = lm_results.predict(X_test)

# %%
evaluate_model(lm_results, X_test,y_test)
# Out:
# R2 Score: 0.22238463652122298
# MSE: 0.00472479094849705
# RMSE: 0.06873711478158688

# %%
# Calculate RMSE.
mean_squared_error(y_test, lm_results.predict(X_test)) ** 0.5
# Out:
# 0.06873711478158688

# %%
pred
# Out:
# array([ 0.02686515, -0.01018157,  0.07505038, -0.01043024,  0.0573272 ,
#        -0.02024049,  0.01447424,  0.03326486, -0.01216025,  0.06968455])

# %%
ols_reg = y_test - lm_results.predict(X_test)

# %%
ols_reg
# Out:
# 2002-01-01   -0.024648
# 2003-01-01   -0.054077
# 2004-01-01    0.024038
# 2005-01-01   -0.014129
# 2006-01-01   -0.098149
# 2007-01-01   -0.025780
# 2008-01-01    0.060801
# 2009-01-01    0.071273
# 2010-01-01   -0.150699
# 2011-01-01   -0.033967
# dtype: float64

# %%
ols_reg.mean()
# Out:
# -0.024533804678537628

# %%
print(abs(ols_reg).sum())
print(abs(residuals_ridge).sum())
# Out:
# 0.5575621705691887
# 0.47336434270411143

# %%
(abs(ols_reg).sum()/abs(residuals_ridge).sum())**-1
# Out:
# 0.8489893462837989

# %%
df = aggr

# %%
print(interpret_dftest(adfuller(df['world_methane'].diff(1).diff(1).dropna())))
print(interpret_dftest(adfuller(df['temp_anomaly'].diff(1).dropna())))
print(interpret_dftest(adfuller(df['temp_anomaly'].diff(1).diff(1).dropna())))
print(interpret_dftest(adfuller(df['world_carbon'].diff(1).diff(1).dropna())))
# Out:
# Test Statistic   -6.679441e+00
# p-value           4.380015e-09
# dtype: float64
# Test Statistic   -5.046365
# p-value           0.000018
# dtype: float64
# Test Statistic   -4.639639
# p-value           0.000109
# dtype: float64
# Test Statistic   -6.015000e+00
# p-value           1.541210e-07
# dtype: float64

# %%
#df = df[['world_methane_diff_1', 'world_methane_diff_2', 'temp_a_diff_1','temp_a_diff_2', 'world_carbon_diff_2']]
df = df[['world_methane_diff_2', 'world_carbon_diff_2', 'temp_a_diff_1', 'target']]

# %%
ss = StandardScaler()
array = ss.fit_transform(df )

# %%
array = pd.DataFrame(array)

# %%
array.columns = df.columns
array.index = df.index

# %%
df_train, df_test = train_test_split(df,
                               test_size = 0.25,
                               shuffle = False)

# %%
# What am I missing?

train, test = train_test_split(array,
                               test_size = 0.25,
                               shuffle = False)

# %%
model = VAR(train)
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)

# %%
# Fit our model and use AIC to select the value of p.

ts_model = model.fit(maxlags=6, # what is the largest possible value of p?
                     ic='aic')   # what "information criterion" (ic) will we use to decide what's "best?"

# %%
# What is the order of our autoregressive model? 
ts_model.k_ar
# Out:
# 2

# %%
# Check out the summary of our model!
ts_model.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 05, Sep, 2020
# Time:                     17:53:29
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -68.7677
# Nobs:                     28.0000    HQIC:                  -69.9569
# Log likelihood:           863.807    FPE:                2.70219e-31
# AIC:                     -70.4806    Det(Omega_mle):     8.86218e-32
# --------------------------------------------------------------------
# Results for equation world_methane_diff_2
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.086131    109530.002611           -0.000           1.000
# L1.world_methane_diff_2        -1.041909         0.276295           -3.771           0.000
# L1.world_carbon_diff_2         -0.163520         0.275331           -0.594           0.553
# L1.temp_a_diff_1               -0.067175  10668357.197980           -0.000           1.000
# L1.target                       0.221984         0.232379            0.955           0.339
# L2.world_methane_diff_2        -0.332757         0.259282           -1.283           0.199
# L2.world_carbon_diff_2          0.211275         0.224037            0.943           0.346
# L2.temp_a_diff_1               -0.199315         0.247096           -0.807           0.420
# L2.target                      -0.068461  10605762.495942           -0.000           1.000
# ==========================================================================================
#
# Results for equation world_carbon_diff_2
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.080589     72061.214353           -0.000           1.000
# L1.world_methane_diff_2         0.178577         0.181778            0.982           0.326
# L1.world_carbon_diff_2          0.117658         0.181144            0.650           0.516
# L1.temp_a_diff_1                0.142612   7018851.059238            0.000           1.000
# L1.target                       0.461387         0.152885            3.018           0.003
# L2.world_methane_diff_2        -0.170525         0.170585           -1.000           0.317
# L2.world_carbon_diff_2         -0.519091         0.147397           -3.522           0.000
# L2.temp_a_diff_1               -0.000490         0.162568           -0.003           0.998
# L2.target                       0.142622   6977669.190038            0.000           1.000
# ==========================================================================================
#
# Results for equation temp_a_diff_1
# ===============================================================================================
#                              coefficient       std. error                t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                          -0.010266         0.000000         -91051503.040           0.000
# L1.world_methane_diff_2        -0.000000         0.000000                -0.488           0.626
# L1.world_carbon_diff_2          0.000000         0.000000                 0.881           0.378
# L1.temp_a_diff_1                0.000053         0.000000              4826.990           0.000
# L1.target                       0.994133         0.000000  4155806825984356.000           0.000
# L2.world_methane_diff_2         0.000000         0.000000                 0.734           0.463
# L2.world_carbon_diff_2         -0.000000         0.000000                -0.026           0.979
# L2.temp_a_diff_1                0.000000         0.000000                 0.075           0.940
# L2.target                      -0.000053         0.000000             -4826.990           0.000
# ===============================================================================================
#
# Results for equation target
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.064932    108293.737241            0.000           1.000
# L1.world_methane_diff_2        -0.385707         0.273176           -1.412           0.158
# L1.world_carbon_diff_2          0.144085         0.272223            0.529           0.597
# L1.temp_a_diff_1               -0.211315  10547943.427822           -0.000           1.000
# L1.target                      -0.356739         0.229756           -1.553           0.120
# L2.world_methane_diff_2        -0.180897         0.256355           -0.706           0.480
# L2.world_carbon_diff_2          0.407598         0.221509            1.840           0.066
# L2.temp_a_diff_1               -0.692893         0.244307           -2.836           0.005
# L2.target                      -0.211892  10486055.232317           -0.000           1.000
# ==========================================================================================
#
# Correlation matrix of residuals
#                         world_methane_diff_2  world_carbon_diff_2  temp_a_diff_1    target
# world_methane_diff_2                1.000000            -0.344323       0.041556  0.625182
# world_carbon_diff_2                -0.344323             1.000000       0.024074  0.032838
# temp_a_diff_1                       0.041556             0.024074       1.000000  0.071574
# target                              0.625182             0.032838       0.071574  1.000000

# %%
# Plot our training data.
ts_model.plot();

# %%
# Plot the forecast looking 3 steps ahead.
ts_model.plot_forecast(12);

# %%
# Plot the forecast looking 50 steps ahead.
ts_model.plot_forecast(50);

# %%
# Save forecasted values
forecast = ts_model.forecast(train.values, len(test))

# %%
df_forecast = ss.inverse_transform(forecast)

# %%
# Loop through columns and get MSE for each
for i in range(test.shape[1]):
    print(f'The test MSE on the {test.columns[i]} data is: {round(mean_squared_error(test.values[:, i], forecast[:, i]), 4)}')
# Out:
# The test MSE on the world_methane_diff_2 data is: 0.4491
# The test MSE on the world_carbon_diff_2 data is: 0.6396
# The test MSE on the temp_a_diff_1 data is: 0.4739
# The test MSE on the target data is: 0.4813

# %% [markdown]
# The test MSE on the world_methane_diff_1 data is: 0.5277
# The test MSE on the temp_a_diff_1 data is: 0.4314
# The test MSE on the world_carbon_diff_2 data is: 0.6773

# %%
# Loop through columns and get MSE for each
for i in range(test.shape[1]):
    print(f'The test MSE on the {df_test.columns[i]} data is: {round(mean_squared_error(df_test.values[:, i], df_forecast[:, i]), 4)}')
# Out:
# The test MSE on the world_methane_diff_2 data is: 45908059786.0364
# The test MSE on the world_carbon_diff_2 data is: 0.3088
# The test MSE on the temp_a_diff_1 data is: 0.007
# The test MSE on the target data is: 0.0071

# %%
df_forecast = pd.DataFrame(df_forecast)
df_forecast.index= df_test.index
df_forecast.columns = df_test.columns

# %%
check = aggr.tail(12)
check = pd.DataFrame(check['temp_anomaly'])
check['temp_a_diff_est'] = df_forecast['temp_a_diff_1']

# %%
 transf = [None]*12
transf[1] = 0.62
for i in range (2,12):
    transf[i] = transf[i-1]+check.iloc[i,1]

# %%
check['pred_temp_anomaly'] = transf

# %%
check = check.iloc[2:]

# %%
mean_squared_error(check['temp_anomaly'],check['pred_temp_anomaly'])
# Out:
# 0.007522429983043341

# %%
ax3 = check.reset_index().plot(kind='scatter',x='index', y='temp_anomaly', color='r')    
ax4 = check.reset_index().plot(kind='scatter',x='index', y='pred_temp_anomaly', color='g', ax=ax3)

# %%
check['how_wrong'] = check['pred_temp_anomaly']-check['temp_anomaly']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
ridge_model = Ridge(alpha=6,fit_intercept=False,solver= 'saga')
ridge_model.fit(X_train_sc, y_train)
pred = ridge_model.predict(X_test_sc)
# Evaluate model using R2.
print(ridge_model.score(X_train_sc, y_train))
print(ridge_model.score(X_test_sc, y_test))
evaluate_model(ridge_model, X_test_sc, y_test)
# Out:
# 0.4405072091275385
# 0.38962324738380505
# R2 Score: 0.38962324738380505
# MSE: 0.003708649148896002
# RMSE: 0.06089867936906351

# %%
check = aggr.tail(12)
check = pd.DataFrame(check['temp_anomaly'])

# %%
hold = [None]*2
hold.extend(list(pred))
len(hold)
# Out:
# 12

# %%
 transf = [None]*12
transf[1] = 0.62
for i in range (2,12):
    transf[i] = transf[i-1]+pred[i-2]

# %%
len(transf)
# Out:
# 12

# %%
check.shape
# Out:
# (12, 1)

# %%
check['pred_temp_anomaly'] = transf
check = check.iloc[2:]

# %%
print(mean_squared_error(check['temp_anomaly'],check['pred_temp_anomaly']))
ax3 = check.reset_index().plot(kind='scatter',x='index', y='temp_anomaly', color='r')    
ax4 = check.reset_index().plot(kind='scatter',x='index', y='pred_temp_anomaly', color='g', ax=ax3)
# Out:
# 0.003893712865371049

# %%
olm_results
# Out:
# 2002-01-01    0.044648
# 2003-01-01   -0.005923
# 2004-01-01    0.065962
# 2005-01-01   -0.015871
# 2006-01-01    0.078149
# 2007-01-01   -0.044220
# 2008-01-01    0.039199
# 2009-01-01    0.008727
# 2010-01-01    0.000699
# 2011-01-01    0.093967
# dtype: float64

# %%
check = aggr.tail(12)
check = pd.DataFrame(check['temp_anomaly'])

# %%
 transf = [None]*12
transf[1] = 0.62
for i in range (2,12):
    transf[i] = transf[i-1]+olm_results[i-2]

# %%
check['pred_temp_anomaly']= transf
check = check.dropna()

# %%
print(mean_squared_error(check['temp_anomaly'],check['pred_temp_anomaly']))
ax3 = check.reset_index().plot(kind='scatter',x='index', y='temp_anomaly', color='r')    
ax4 = check.reset_index().plot(kind='scatter',x='index', y='pred_temp_anomaly', color='g', ax=ax3)
# Out:
# 0.021321325488392263

# %%
plot_acf(aggr['temp_anomaly'],lags = 30)

# %%
plot_pacf(aggr['temp_anomaly'],lags = 24)
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
y_train, y_test = train_test_split(aggr['target'],
                                   test_size = 0.15,
                                   shuffle = False)

# %%
# Starting AIC, p, and q.
best_aic = 99 * (10 ** 16)
best_p = 0
best_q = 0

# Use nested for loop to iterate over values of p and q.
for p in range(5):
    for q in range(5):
        
        # Insert try and except statements.
        try:
            
            # Fitting an ARIMA(p, 1, q) model.
            print(f'Attempting to fit ARIMA({p},1,{q})')
            
            # Instantiate ARIMA model.
            arima = ARIMA(endog = y_train.astype(float).dropna(), # endog = Y variable
                          order = (p,1,q)) # values of p, d, q
            
            # Fit ARIMA model.
            model = arima.fit()

            # Print out AIC for ARIMA(p, 1, q) model.
            print(f'The AIC for ARIMA({p},1,{q}) is: {model.aic}')

            # Is my current model's AIC better than our best_aic?
            if model.aic < best_aic:
                
                # If so, let's overwrite best_aic, best_p, and best_q.
                best_aic = model.aic
                best_p = p
                best_q = q

        except:
            pass
print()
print()
print('MODEL FINISHED!')
print(f'Our model that minimizes AIC on the training data is the ARIMA({best_p},1,{best_q}).')
print(f'This model has an AIC of {best_aic}.')
# Out:
# Attempting to fit ARIMA(0,1,0)
# The AIC for ARIMA(0,1,0) is: -4.187281936177435
# Attempting to fit ARIMA(0,1,1)
# The AIC for ARIMA(0,1,1) is: -32.75104971507655
# Attempting to fit ARIMA(0,1,2)
# The AIC for ARIMA(0,1,2) is: -43.512580159896416
# Attempting to fit ARIMA(0,1,3)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(0,1,3) is: -42.1245042524567
# Attempting to fit ARIMA(0,1,4)
# Attempting to fit ARIMA(1,1,0)
# The AIC for ARIMA(1,1,0) is: -18.661737070087938
# Attempting to fit ARIMA(1,1,1)
# The AIC for ARIMA(1,1,1) is: -36.74400009586084
# Attempting to fit ARIMA(1,1,2)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(1,1,2) is: -28.741393557100324
# Attempting to fit ARIMA(1,1,3)
# The AIC for ARIMA(1,1,3) is: -39.43534220829379
# Attempting to fit ARIMA(1,1,4)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:716: RuntimeWarning: invalid value encountered in log
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# Attempting to fit ARIMA(2,1,0)
# The AIC for ARIMA(2,1,0) is: -22.36042736036363
# Attempting to fit ARIMA(2,1,1)
# The AIC for ARIMA(2,1,1) is: -36.880162709070405
# Attempting to fit ARIMA(2,1,2)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(2,1,2) is: -39.915161368509146
# Attempting to fit ARIMA(2,1,3)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(2,1,3) is: -39.32186970898634
# Attempting to fit ARIMA(2,1,4)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(2,1,4) is: -42.46584849111257
# Attempting to fit ARIMA(3,1,0)
# The AIC for ARIMA(3,1,0) is: -34.18079925854447
# Attempting to fit ARIMA(3,1,1)
# The AIC for ARIMA(3,1,1) is: -32.39700918433947
# Attempting to fit ARIMA(3,1,2)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(3,1,2) is: -32.87180053757673
# Attempting to fit ARIMA(3,1,3)
# Attempting to fit ARIMA(3,1,4)
# Attempting to fit ARIMA(4,1,0)
# The AIC for ARIMA(4,1,0) is: -32.364609354133464
# Attempting to fit ARIMA(4,1,1)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(4,1,1) is: -36.93902519896842
# Attempting to fit ARIMA(4,1,2)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The AIC for ARIMA(4,1,2) is: -34.20955633248438
# Attempting to fit ARIMA(4,1,3)
# The AIC for ARIMA(4,1,3) is: -39.809900608514326
# Attempting to fit ARIMA(4,1,4)
#
#
# MODEL FINISHED!
# Our model that minimizes AIC on the training data is the ARIMA(0,1,2).
# This model has an AIC of -43.512580159896416.
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)

# %%
# Instantiate best model.
model = ARIMA(endog = y_train.astype(float).dropna(), # endog = Y variable
              order = (2,1,4))

# Fit ARIMA model.
arima = model.fit()

# Generate predictions based on test set.
preds = model.predict(params = arima.params,
                      start = y_test.index[0],
                      end = y_test.index[-1])

# Plot data.
plt.figure(figsize=(10,6))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train).diff(), color = 'blue')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test).diff(), color = 'orange')

# Plot predicted test values.
plt.plot(y_test.index, preds, color = 'green')

plt.title(label = 'Once-Differenced Global Mean Temperature with ARIMA(0, 1, 3) Predictions', fontsize=16)
plt.show();
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /Library/Python/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
features = ['world_methane_diff_2', 'world_carbon_diff_2', 'temp_a_diff_2', 'temp_a_diff_1']
X= aggr[features]
y= aggr['target']
X_sc = ss.fit_transform(X)

# %%
pca = PCA()
X_pca = pca.fit(X_sc)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
print(X.shape, y.shape)
# Out:
# (40, 4) (40,)

# %%
pf = PolynomialFeatures(degree = 1)
X_new = pf.fit_transform(X)
print(X_new.shape)
# Out:
# (40, 5)

# %%
# Train/test split our data.
X_train, X_test, y_train, y_test = train_test_split(X_new,
                                                    y,
                                                    random_state = 42,
                                                    shuffle = False)

# %%
# Standardize X_train.
X_train = ss.fit_transform(X_train)

# Standardize X_test.
X_test = ss.transform(X_test)

# %%
pipe = Pipeline([('pf', PolynomialFeatures()),
                 ('scaler', StandardScaler()),
                 ('pca', PCA()),
                 ('ridge', Ridge())])
pipe_params = { 'pf__degree' : [1,3],
                'pca__n_components' : [5,7,9,11],
                'ridge__alpha':[.0001,.5,1,3,5,9,13]}
pipe_gridsearch = GridSearchCV(pipe,
                                 pipe_params,
                                 cv = 5,
                                verbose = 1,
                                n_jobs=8)

# %%
y_train.shape
# Out:
# (30,)

# %%
pipe_gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 280 out of 280 | elapsed:   16.4s finished
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('pf', PolynomialFeatures()),
#                                        ('scaler', StandardScaler()),
#                                        ('pca', PCA()), ('ridge', Ridge())]),
#              n_jobs=8,
#              param_grid={'pca__n_components': [5, 7, 9, 11],
#                          'pf__degree': [1, 3],
#                          'ridge__alpha': [0.0001, 0.5, 1, 3, 5, 9, 13]},
#              verbose=1)

# %%
pipe_gridsearch.best_score_
# Out:
# -0.12168483997825083

# %%
pipe_gridsearch.best_params_
# Out:
# {'pca__n_components': 5, 'pf__degree': 1, 'ridge__alpha': 13}

# %%
pf = PolynomialFeatures(degree=3)
X_new = pf.fit_transform(X)

# %%
# Instantiate PCA with 10 components.
pca = PCA(n_components = 5, random_state = 42)

# Fit PCA to training data.
pca.fit(X_train)
Z_train = pca.transform(X_train)
Z_test = pca.transform(X_test)

# %%
Z_train = pca.transform(X_train)
Z_test = pca.transform(X_test)

# %%
ridge_model = Ridge(alpha=13)
ridge_model.fit(Z_train, y_train)

# Evaluate model using R2.
print(ridge_model.score(Z_train, y_train))
print(ridge_model.score(Z_test, y_test))
evaluate_model(ridge_model, Z_test, y_test)
# Out:
# 0.42854228523304694
# 0.32132043971083335
# R2 Score: 0.32132043971083335
# MSE: 0.0041236570083169775
# RMSE: 0.06421570686613189

# %%
pred = ridge_model.predict(Z_test)

# %%
y_test
# Out:
# 2002-01-01    0.02
# 2003-01-01   -0.06
# 2004-01-01    0.09
# 2005-01-01   -0.03
# 2006-01-01   -0.02
# 2007-01-01   -0.07
# 2008-01-01    0.10
# 2009-01-01    0.08
# 2010-01-01   -0.15
# 2011-01-01    0.06
# Name: target, dtype: float64

# %%
check = aggr.tail(12)
check = pd.DataFrame(check['temp_anomaly'])
hold = [None]*2
hold.extend(list(pred))
check['temp_a_diff_est'] = hold
check
# Out:
#             temp_anomaly  temp_a_diff_est
# 2000-01-01          0.43              NaN
# 2001-01-01          0.57              NaN
# 2002-01-01          0.62         0.022348
# 2003-01-01          0.64        -0.005749
# 2004-01-01          0.58         0.070373
# 2005-01-01          0.67        -0.007999
# 2006-01-01          0.64         0.051442
# 2007-01-01          0.62        -0.009659
# 2008-01-01          0.55         0.017592
# 2009-01-01          0.65         0.029650
# 2010-01-01          0.73        -0.011086
# 2011-01-01          0.58         0.067089

# %%
check.iloc[i,1]
# Out:
# 0.06708873625315784

# %%
 transf = [None]*12
transf[1] = 0.62
for i in range (2,12):
    transf[i] = transf[i-1]+check.iloc[i,1]

# %%
check['pred_temp_anomaly'] = transf
check = check.iloc[2:]
print(mean_squared_error(check['temp_anomaly'],check['pred_temp_anomaly']))
ax3 = check.reset_index().plot(kind='scatter',x='index', y='temp_anomaly', color='r')    
ax4 = check.reset_index().plot(kind='scatter',x='index', y='pred_temp_anomaly', color='g', ax=ax3)
# Out:
# 0.017859605678797096

# %%
check['error'] = abs(check['temp_anomaly']-check['pred_temp_anomaly'])
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
check['error'].mean()
# Out:
# 0.17800337391078203

# %%
check['error'].sum()
# Out:
# 1.7800337391078207

# %% [markdown]
# pf =4, alpha = .0001 n_c = 10

# %% [markdown]
# pf = 13, alpha = .001, n_c = 25
